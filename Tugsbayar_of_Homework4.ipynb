# %% [markdown]
# <a href="https://colab.research.google.com/github/PerfectoHeppi/AI-Academy/blob/main/Tugsbayar_of_Homework4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Too Taah togloom
import random
random_number = random.randint(1,50)
for i in range(5):
  guess = int(input("Guess a number between 1-50: "))
  if(guess == random_number):
    print("You got it!!!")
    break
  else:
    print("Wrong!!!")
if(guess != random_number):
  print("Game over!")
# Out:
# Wrong!!!
# Wrong!!!

# %%
# Niilber ba dundaj
total = 0
for i in range(101):
    total += i
print(total)
# Out:
# 5050

# %%
# Niilber ba dundaj (3t huvaagddag)
total = 0
for i in range(101):
  if(i % 3 == 0):
    total += i
print(total)
# Out:
# 1683

# %%
# Odon gurvaljin
star = "*"
for i in range(5):
  print(f"{star}")
  star += "*"
# Out:
# *
# **
# ***
# ****
# *****

# %%
# Buteh hurd
for i in range(1,10):
  print("")
  print(f"{i} iin hurd")
  print("")
  for j in range(1,10):
    print(f"{i} * {j} = {i * j}")
# Out:
# 1 iin hurd
#
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 3 = 3
# 1 * 4 = 4
# 1 * 5 = 5
# 1 * 6 = 6
# 1 * 7 = 7
# 1 * 8 = 8
# 1 * 9 = 9
#
# 2 iin hurd
#
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
#
# 3 iin hurd
#
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
#
# 4 iin hurd
#
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
#
# 5 iin hurd
#
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
#
# 6 iin hurd
#
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
#
# 7 iin hurd
#
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
#
# 8 iin hurd
#
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# ...

# %%
# Dungiin tailan
import random
exam_1 = random.randint(20,100)
exam_2 = random.randint(40,100)
exam_3 = random.randint(80,100)
exam_4 = random.randint(10,100)
exam_5 = random.randint(30,100)
exam_6 = random.randint(50,100)
exam_list = [exam_1, exam_2, exam_3, exam_4, exam_5, exam_6]
print("shalgaltiin hariunuud: ", exam_list)
highest = 0
lowest = 0
average = 0
print(len(exam_list))
for i in range(len(exam_list)):
    average =+ exam_list[i]
average = average / len(exam_list)
highest = max(exam_list)
lowest = min(exam_list)
print(highest)
print(lowest)
print(average)
# Out:
# shalgaltiin hariunuud:  [56, 90, 85, 62, 71, 99]
# 6
# 99
# 56
# 16.5
