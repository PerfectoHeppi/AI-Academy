# %%
def greet():
    print("Hi there!")
def say_goodbye():
    print("Goodbye!")
def cheer():
    print("You can do it!")
def thank_you():
    print("Thank you for learning")
def surprise():
    print("Surprise!")
for i in range(3):
    greet()
for i in range(2):
    say_goodbye()
for i in range(4):
    cheer()
thank_you()
for i in range(5):
    surprise()
# Out:
# Hi there!
# Hi there!
# Hi there!
# Goodbye!
# Goodbye!
# You can do it!
# You can do it!
# You can do it!
# You can do it!
# Thank you for learning
# Surprise!
# Surprise!
# Surprise!
# Surprise!
# Surprise!

# %%
print("hello world")
# Out:
# hello world
